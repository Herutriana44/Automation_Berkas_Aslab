# %% [markdown]
# # Membuat DataFrame

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("Iris.csv")

# %%
my_data = np.array([[5.1, 3.5, 1.4, 0.2],[4.9, 3.0, 1.4, 0.2], [4.7, 3.2, 1.3, 0.2], [4.6, 3.1, 1.5, 0.2], [5.0, 3.6, 1.4, 0.2]])

# %%
column_names = ['sepal.length', 'sepal.width', 'petal.lenght', 'petal.width']

# %%
data_frame = pd.DataFrame(data=my_data, columns=column_names)

# %%
my_data = {
    'sepal.length' : [5.1, 4.9, 4.7, 4.6, 5.0],
    'sepal.width' : [3.5, 3.0, 3.2, 3.1, 3.6],
    'petal.length' : [1.4, 1.4, 1.3, 1.5, 1.4],
    'petal.width' : [0.2] * 5
}

# %%
data_frame = pd.DataFrame(my_data)

# %%
data_frame
# Out:
#    sepal.length  sepal.width  petal.length  petal.width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %% [markdown]
# # Menambahkan Kolom Baru

# %%
data_frame["species"] = "Iris-setosa"

# %%
data_frame
# Out:
#    sepal.length  sepal.width  petal.length  petal.width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# # Menentukan Subset

# %%
data_frame["species"].tolist()
# Out:
# ['Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa']

# %%
data_frame.iloc[[2]]
# Out:
#    sepal.length  sepal.width  petal.length  petal.width      species
# 2           4.7          3.2           1.3          0.2  Iris-setosa

# %%
data_frame[3:5]
# Out:
#    sepal.length  sepal.width  petal.length  petal.width      species
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# # Menampilkan Informasi Dataframe Pandas

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  5 non-null      float64
#  1   sepal.width   5 non-null      float64
#  2   petal.length  5 non-null      float64
#  3   petal.width   5 non-null      float64
#  4   species       5 non-null      object
# dtypes: float64(4), object(1)
# memory usage: 328.0+ bytes

# %%
data_frame.dtypes
# Out:
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# species          object
# dtype: object

# %%
data_frame.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count      5.000000     5.000000      5.000000          5.0
# mean       4.860000     3.280000      1.400000          0.2
# std        0.207364     0.258844      0.070711          0.0
# min        4.600000     3.000000      1.300000          0.2
# 25%        4.700000     3.100000      1.400000          0.2
# 50%        4.900000     3.200000      1.400000          0.2
# 75%        5.000000     3.500000      1.400000          0.2
# max        5.100000     3.600000      1.500000          0.2

# %%
data_frame['species'].value_counts()
# Out:
# Iris-setosa    5
# Name: species, dtype: int64

# %%
data_frame['species'].unique()
# Out:
# array(['Iris-setosa'], dtype=object)

# %%
import random

df = pd.DataFrame({
    'Panjang' : [random.randint(0, 100) for i in range(0, 5)]
})

# %%
df.head()
# Out:
#    Panjang
# 0       67
# 1       38
# 2       50
# 3       22
# 4       10
